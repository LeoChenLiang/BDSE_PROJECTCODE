# %%
import os
import json
import re
import emoji
import emojiswitch

# %%
cls_http = r'http\S+'   #擷取http
cls_www  = r'www\S+'    #擷取www
cls_emojiword = r':.*:' #擷取轉成文字的emoji
cls_Bnum = r'[bB]\d\d?-?\d?\d?\s?' #擷取(B2...)
cls_Fnum = r'\n\d\.'    #擷取開頭數字(1.)
cls_letter =r'\n[a-z].' #擷取開頭英文(a.)
cls_blank = r'\s\.?-?'    #擷取空白符號

# %%
file_path = "Dcard_csv(data)"
if not os.path.exists(file_path):
        os.makedirs(file_path)

        
file = "Dcard_data"
allfile = os.listdir(file)

d_arcital = []
d_comment = []
d_sub_content = []


for file_name in allfile:
    with open (f'{file}/{file_name}' , 'r' ,encoding = 'utf-8') as json_obj:
        text = json.load(json_obj)
        for obj in text:
            art_date = obj["createdAt"][:10]  
            f = open (f"Dcard_csv(data)/{art_date}.csv" , "a" , encoding = 'utf-8')
            #去除網址連結
            no_url = re.sub(cls_http,'\n' , obj['content'])
            no_wwww = re.sub(cls_www,'\n' , no_url)
            #print(no_wwww)

            #去除開頭的數字or英文
            no_num = re.sub(cls_Fnum,'' , no_wwww)
            no_letter = re.sub(cls_letter,'' , no_num)
            #print(no_letter)
            
            
            #擷取空白符號(\r\n、\n\)
            no_rn = re.sub(cls_blank,'',no_letter)+'\n'
            #print(no_rn)
            
        
            f.write(no_rn)
            f.seek(0.0)
            f.close()

             
            #判斷文章是否有留言
            if "comment" in obj:
                for objc in obj["comment"]:
                    com_date = objc["createdAt"][:10]
                    f_comment = open (f"Dcard_csv(data)/{com_date}.csv" , "a" , encoding = 'utf-8')
                    
                    #去除網址連結
                    comment = re.sub(cls_http,'\n',objc['content'])
                    de_www = re.sub(cls_www,'\n',comment)
                    #print(de_www)
                    
                    #去除開頭的數字
                    cls_num = re.sub(cls_Fnum,'' , de_www)
                    #print(cls_num)
                    
                    #去除開頭的英文
                    #clr_letter = re.sub(cls_letter,'' , cls_num)
                    #print(cls_letter)
                    
                    #去除bB+數字
                    de_Bnum = re.sub(cls_Bnum, '\n', cls_num)
                    #print(de_Bnum)
                    
                    #擷取空白符號(\r\n、\n\)
                    cls_rn = re.sub(cls_blank,'',de_Bnum)
                    
                    if cls_rn != '' :
                        final_content = cls_rn+'\n'
                        #print(final_content)
                    
                        f_comment.write(final_content)
                        f_comment.seek(0.0)
                        f_comment.close()



                       
                        #判斷是否有流言下面是否有留言
                        if "subComment" in objc:
                            for sub_objc in objc["subComment"]:
                                sub_com_date = sub_objc["createdAt"][:10]
                                f_sub_comment = open (f"Dcard_csv(data)/{sub_com_date}.csv" , "a" , encoding = 'utf-8')

                                #去除網址連結
                                sub_comment = re.sub(cls_http,'\n',sub_objc['content'])
                                sub_www = re.sub(cls_www,'\n',sub_comment)
                                #print(sub_comment)
                            
                                #去除開頭的數字or英文
                                clr_num = re.sub(cls_Fnum, '\n' , sub_www)
                                #print(clr_num)
                                
                                #去除bB+數字
                                clr_bnum = re.sub(cls_Bnum, '\n', clr_num)
                                #print(clr_bnum)
                            
                                #將/r/n取代成/n
                                clr_rn = re.sub(cls_blank,'',clr_bnum)
                                
                                if clr_rn != '' :
                                    final_sub_content = clr_rn +'\n'
                                    
                                    f_sub_comment.write(final_sub_content)
                                    f_sub_comment.seek(0.0)
                                    f_sub_comment.close()

# %%
file_path = "Dcard_csv(data)"
if not os.path.exists(file_path):
        os.makedirs(file_path)

        
file = "Dcard_data"
allfile = os.listdir(file)

d_arcital = []
d_comment = []
d_sub_content = []


for file_name in allfile:
    with open (f'{file}/{file_name}' , 'r' ,encoding = 'utf-8') as json_obj:
        text = json.load(json_obj)
        for obj in text:
            art_date = obj["createdAt"][:10]  
            f = open (f"Dcard_csv(data)/{art_date}.csv" , "a" , encoding = 'utf-8')
            
#             if art_date == "2022-08-19" :
#                 print(file_name)
#                 print(obj['content'])
            #去除網址連結
#             no_url = re.sub(cls_http,'\n' , obj['content'])
#             no_wwww = re.sub(cls_www,'\n' , no_url)
#             #print(no_wwww)

#             #去除開頭的數字or英文
#             no_num = re.sub(cls_Fnum,'' , no_wwww)
#             no_letter = re.sub(cls_letter,'' , no_num)
#             #print(no_letter)
            
            
#             #擷取空白符號(\r\n、\n\)
#             no_rn = re.sub(cls_blank,'',no_letter)+'\n'
#             #print(no_rn)
            
        
#             f.write(no_rn)
#             f.seek(0.0)
#             f.close()

             
            #判斷文章是否有留言
            if "comment" in obj:
                for objc in obj["comment"]:
                    com_date = objc["createdAt"][:10]
                    f_comment = open (f"Dcard_csv(data)/{com_date}.csv" , "a" , encoding = 'utf-8')
                    if com_date == "2022-08-19" :
                        print(file_name)
                        print(objc)
                   
                     #去除網址連結
#                     comment = re.sub(cls_http,'\n',objc['content'])
#                     de_www = re.sub(cls_www,'\n',comment)
#                     #print(de_www)
                    
#                     #去除開頭的數字
#                     cls_num = re.sub(cls_Fnum,'' , de_www)
#                     #print(cls_num)
                    
#                     #去除開頭的英文
#                     #clr_letter = re.sub(cls_letter,'' , cls_num)
#                     #print(cls_letter)
                    
#                     #去除bB+數字
#                     de_Bnum = re.sub(cls_Bnum, '\n', cls_num)
#                     #print(de_Bnum)
                    
#                     #擷取空白符號(\r\n、\n\)
#                     cls_rn = re.sub(cls_blank,'',de_Bnum)
                    
#                     if cls_rn != '' :
#                         final_content = cls_rn+'\n'
#                         #print(final_content)
                    
#                         f_comment.write(final_content)
#                         f_comment.seek(0.0)
#                         f_comment.close()



                       
                        #判斷是否有流言下面是否有留言
                    if "subComment" in objc:
                        for sub_objc in objc["subComment"]:
                            sub_com_date = sub_objc["createdAt"][:10]
                            f_sub_comment = open (f"Dcard_csv(data)/{sub_com_date}.csv" , "a" , encoding = 'utf-8')
                            
#                             if sub_com_date == "2022-08-19" :
#                                 print(file_name)
#                                 print(sub_objc)
                            
                            

#                                 #去除網址連結
#                                 sub_comment = re.sub(cls_http,'\n',sub_objc['content'])
#                                 sub_www = re.sub(cls_www,'\n',sub_comment)
#                                 #print(sub_comment)
                            
#                                 #去除開頭的數字or英文
#                                 clr_num = re.sub(cls_Fnum, '\n' , sub_www)
#                                 #print(clr_num)
                                
#                                 #去除bB+數字
#                                 clr_bnum = re.sub(cls_Bnum, '\n', clr_num)
#                                 #print(clr_bnum)
                            
#                                 #將/r/n取代成/n
#                                 clr_rn = re.sub(cls_blank,'',clr_bnum)
                                
#                                 if clr_rn != '' :
#                                     final_sub_content = clr_rn +'\n'
                                    
#                                     f_sub_comment.write(final_sub_content)
#                                     f_sub_comment.seek(0.0)
#                                     f_sub_comment.close()
# Out:
# 237914929.json
# {'id': 'e3f05b3f-c71b-4725-879e-c222cce5abaf', 'createdAt': '2022-08-19 21:55', 'content': 'https://www.dcard.tw/f/blockchain/p/239574177?ref=ios', 'subCommentCount': 0}

# %%
# file_path = "Dcard_csv(data)"
# if not os.path.exists(file_path):
#         os.makedirs(file_path)

        
# file = "Dcard_data"
# allfile = os.listdir(file)


# for file_name in allfile:
#     with open (f'{file}/{file_name}' , 'r' ,encoding = 'utf-8') as json_obj:
#         text = json.load(json_obj)
#         for obj in text:
#             art_date = obj["createdAt"][:10]
# #             print(art_date)
#             f = open (f"Dcard_csv(data)/{art_date}.csv" , "a" , encoding = 'utf-8')
#             #去除網址連結
#             no_url = re.sub(cls_http,'\n' , obj['content'])
#             no_wwww = re.sub(cls_www,'\n' , no_url)
#             #print(no_wwww)
            
#             #去除開頭的數字or英文
#             no_num = re.sub(cls_Fnum,'' , no_wwww)
#             no_letter = re.sub(cls_letter,'' , no_num)
#             #print(no_letter)
            
#             #將/r/n取代成/n
#             no_rn = re.sub(r'\\r\\n','\n',no_letter)
#             #print(no_rn)
            
#             #將表情符號轉成文字
#             emoji_to_word = emoji.demojize(no_rn)
            
#             #將表情符號的文字清除
#             de_emoji = re.sub(cls_emojiword,'',emoji_to_word)
#             #print(de_emoji)
            
# #             no_n = de_emoji.replace('\n', '')
# #             print(no_n)
#             #寫入文章
#             f.write(de_emoji)
#             f.seek(0.0)
            
            
#             #判斷文章是否有留言
#             if "comment" in obj:
#                 for objc in obj["comment"]:
#                     com_date = objc["createdAt"][:10]
#                     if com_date == "2021-05-04":
#                         print(file_name)
#                         print(objc['content'])
# #                     print(com_date)
#                     f_comment = open (f"Dcard_csv(data)/{com_date}.csv" , "a" , encoding = 'utf-8')
                    
#                     #去除網址連結
#                     comment = re.sub(cls_http,'\n',objc['content'])
#                     de_www = re.sub(cls_www,'\n',comment)
#                     #print(de_www)
                    
#                     #去除開頭的數字or英文
#                     cls_num = re.sub(cls_Fnum,'' , de_www)
#                     #print(cls_num)
#                     #clr_letter = re.sub(cls_letter,'' , cls_num)
#                     #print(cls_letter)
#                     #將/r/n取代成/n
#                     cls_rn = re.sub(r'\\r\\n','\n',cls_num)
                    
#                     #去除bB+數字
#                     de_Bnum = re.sub(cls_Bnum, '', cls_rn)
#                     #print(de_Bnum)


#                     #將表情符號轉成文字
#                     emoji_to_word = emojiswitch.demojize(de_Bnum,lang="zh")
#                     #print(emoji_to_word)
#                     f.write(emoji_to_word)
#                     f.seek(0.0)

                       
#                     #判斷是否有流言下面是否有留言
#                     if "subComment" in objc:
#                         for sub_objc in objc["subComment"]:
#                             sub_com_date = sub_objc["createdAt"][:10]
#                             if com_date == "2021-05-04":
#                                 print(sub_objc['content'])
# #                             print(sub_com_date)
#                             f_sub_comment = open (f"Dcard_csv(data)/{sub_com_date}.csv" , "a" , encoding = 'utf-8')

#                             #去除網址連結
#                             sub_comment = re.sub(cls_http,'\n',sub_objc['content'])
#                             sub_www = re.sub(cls_www,'\n',sub_comment)
#                             #print(sub_comment)
                            
#                             #去除開頭的數字or英文
#                             clr_num = re.sub(cls_Fnum,'' , sub_www)
                            
#                             #將/r/n取代成/n
#                             no_rn = re.sub(r'\\r\\n','\n',clr_num)
#                             #print(no_rn)
                            
#                             #去除bB+數字
#                             clr_bnum = re.sub(cls_Bnum, '', no_rn)
#                             #print(clr_bnum)
                            
#                             #去除網址
#                             clr_url = re.sub(cls_http, '', clr_bnum)
#                             print(clr_url)
#                             #將表情符號轉成文字
#                             #subemoji_to_word = emojiswitch.demojize( clr_url , lang="zh" )
#                             #print(emoji_to_word)
#                             f.write(clr_url)
#                             f.seek(0.0)


                            
                            
                            
# f.close()
# f_comment.close()
# f_sub_comment.close()
